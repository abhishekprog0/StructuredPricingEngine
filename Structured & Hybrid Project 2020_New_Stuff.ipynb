# %% [markdown]
# <img src="Project Description.PNG" alt="Drawing" style="width: 800px;"/>

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (0.1.55)
# Requirement already satisfied: numpy>=1.15 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.18.5)
# Requirement already satisfied: pandas>=0.24 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.0.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: lxml>=4.5.1 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (4.5.2)
# Requirement already satisfied: pytz>=2017.2 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/abhishekmukherjee/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import random
import yfinance as yf
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


size = 18
params = {'legend.fontsize': 'large',
          'figure.figsize': (15,8),
          'axes.labelsize': size * 0.8,
          'axes.titlesize': size * 0.95,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}

plt.rcParams.update(params)

# %%
class DataReader:
    
    def __init__(self):
        pass
    
    def getStockData(self):
        
        price = yf.download("^STOXX50E", start = "2019-12-01", end = "2020-12-3")['Adj Close'].reset_index()
        return prices
    
    def getLiborData(self):
        
        pass

# %% [markdown]
# ### The GBM Model for STOXX50E simulation

# %%
price = yf.download("^STOXX50E", start = "2019-12-01", end = "2020-12-3")['Adj Close'].reset_index()

plt.plot(price['Date'], price['Adj Close'], label = "STOXX50E")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Maximum Likelihood Estimator for Drift and Volatility of STOXX50E

# %%
n = len(price['Date'])
delta = 1
x_bar = np.sum(np.log(price['Adj Close']/price['Adj Close'].shift(1)))/n

print ("MLE for Drift parameter(μ) : " + str(x_bar))
# Out:
# MLE for Drift parameter(μ) : -0.0001169688553969635

# %%
price_bar = np.log(price['Adj Close']/price['Adj Close'].shift(1)) - x_bar
vol = np.sum(np.power(price_bar, 2))/n
vol = np.sqrt(vol)
print ("MLE for Volatility parameter(σ) : " + str(vol))
# Out:
# MLE for Volatility parameter(σ) : 0.020456189051262293

# %% [markdown]
# ### Simulating Geometric Brownian Motion

# %%
def Brownian(seed, N):
    
    np.random.seed(seed)                         
    dt = 1                                    # time step
    b = np.random.normal(0., 1., int(N))*np.sqrt(dt)  # brownian increments
    W = np.cumsum(b)                             # brownian path
    return W, b

seed =10
N  = n     # increments

seed_list = [90]
k = 1
for seed in seed_list:
    
    #print ("Simulation: " + str(k))
    print (seed)
    k += 1
    W = Brownian(seed, N)[0]
    W = np.insert(W, 0, 0.)  

    def GBM(So, mu, sigma, W, T, N):    
        t = np.ones((N + 1))
        S = []
        S.append(So)
        for i in range(1,int(N+1)):
            
            #drift = (mu - 0.5 * sigma**2) * t[i]
            drift = (mu) * t[i]
            diffusion = sigma * W[i-1]
            S_temp = So*np.exp(drift + diffusion)
            S.append(S_temp)
        return S, t

    So = price['Adj Close'].iloc[-1]
    mu = x_bar
    sigma = vol
    #pranav
    # mu = 0.2646
    # sigma = 0.247
    W = Brownian(seed, N)[0]
    T = 1.

    GBM_avg = np.zeros((1000, 252))

    for i in range(1000):
        soln = GBM(So, mu, sigma, W, T, N)[0]    # Exact solution
        soln = soln[:-1]
        GBM_avg[i] = soln
    gbm_avg = GBM_avg.mean(axis = 0)
    t = GBM(So, mu, sigma, W, T, N)[1]       # time increments for  plotting
    
    rng = pd.date_range('2020-12-4', periods=len(gbm_avg), freq='B')
    price_gbm = pd.DataFrame({ 'Date': rng, 'Close': gbm_avg}) 

    plt.title('Simulation: ' + str(k- 1) + '\nSTOXX50E vs Geometric Brownian Motion with drift: ' + str(round(mu, 5)) + " and Volatility: " + str(round(sigma, 5)))
    plt.plot(price['Date'], price['Adj Close'], label = "STOXX50E")
    plt.plot(price_gbm['Date'], price_gbm['Close'], color = 'r', label = "Geometric Brownian Motion")
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
# Out:
# 90

# %% [markdown]
# ## The Vasicek Model for USD LIBOR rate simulation
# dr(t) = k[θ − r(t)]dt + σdW(t)

# %%
def vasicek(r0, K, theta, sigma, T=1., N=252, seed=777):    
    
    np.random.seed(seed)
    dt = T/float(N)    
    rates = [r0]
    for i in range(N):
        dr = K*(theta-rates[-1])*dt + sigma*np.random.normal()
        rates.append(rates[-1] + dr)
    return range(N+1), rates

# %%
xo, yo = vasicek(0.01875, 0.20, -0.1, 0.001, 1, 252)

plt.title("Example: 3 month LIBOR rate simulation using Vasicek Model with random parameters")
plt.plot(xo,yo)
plt.show()

# %% [markdown]
# ### Get historical 3-month LIBOR rate

# %%
libor = pd.read_csv('3-month-libor.csv').fillna(method = 'bfill').fillna(method = 'ffill')

#libor['3M'] /= 100
libor['Date'] = libor['Date'].astype('datetime64[ns]')
libor = libor.sort_values(by = ['Date'])
df = libor.iloc[-250:-100]
df_test = libor.iloc[-100:]

plt.title("3-month historical LIBOR")
plt.plot(libor['Date'], libor['3M'])
plt.show()
plt.plot(df['Date'], df['3M'])
plt.show()

# %%
df
# Out:
#            Date      3M
# 8532 2019-10-09  1.9843
# 8533 2019-10-10  1.9861
# 8534 2019-10-11  2.0009
# 8535 2019-10-14  2.0009
# 8536 2019-10-15  2.0021
# ...         ...     ...
# 8677 2020-05-06  0.4476
# 8678 2020-05-07  0.4346
# 8679 2020-05-11  0.4335
# 8680 2020-05-12  0.4240
# 8681 2020-05-13  0.3924
#
# [150 rows x 2 columns]

# %%
def param_opt (df):
    r = np.array(df['3M'])
    a = r[:len(r)-1]
    r = r[1:]
    
    x = np.array(df['3M'])
    b = x[:len(x)-1]
    
    s0 = (np.sum(r) - r[-1]) / len(r)
    s1 = np.mean(r)
    s00 = np.sum(a**2) / len(r)
    s01 = np.sum(b*r) / len(r)
    
    rn = (s1*s00 - s0*s01) / ((s0*s1) - (s0**2) + (s00-s01))
    k = np.log((s0-np.mean(x)) / (s1 - np.mean(x)) ) / 1
    beta = 1/k * (1 - np.exp(k))
    
    def B(s):
        return (1 - np.exp(-k))/k
    
    u = np.mean(x)
    m = np.array([])

    for i in range(1,len(x)):
        g = (u * k * B(k)) + (x[i-1] * (1- (k * B(k)))) 
        m = np.append(m,g)
        
    sig = 1/((len(x)*beta)*(1 - k*beta/2)) * np.sum((r - m)**2)
    
    return rn,k,beta,sig

# %%
rn, k , beta, sig = param_opt(df)

# %%
df['3M'].iloc[-1], k, beta, sig
# Out:
# (0.3924, 0.660524944419521, -1.4167644498151053, -0.024323795165652265)

# %%
xo, yo = vasicek(df['3M'].iloc[-1], k, beta, sig, 1, 100, seed = 3)

rng = pd.date_range(df['Date'].iloc[-1], periods=101 , freq='B')
lib = pd.DataFrame({ 'Date': rng, '3M': yo}) 


plt.title('Simulation: 3-month LIBOR curve using Vasicek Model')
plt.plot(df['Date'], df['3M'], label = "Historical")
plt.plot(df_test['Date'], df_test['3M'], color = 'g', label = "Actual")
plt.plot(lib['Date'], lib['3M'], color = 'r', label = "Predicted")

plt.xlabel('Date')
plt.ylabel('Rate')
plt.legend()
plt.show()

# %% [markdown]
# # NEW STUFF

# %%
r1 = np.array(df['3M'])
r2 = r1[:len(r1)-1]
r3 = r1[1:]
 
    
a = len(r1) * np.sum(r2*r3)
b = np.sum(r3) * np.sum(r2)
c = len(r1) * np.sum(r2**2)
d = np.sum(r2) ** 2

drift = -np.log((a-b)/(c-d))
drift
# Out:
# -0.013301846785976783

# %%
k = 1/(len(r1) *(1 - np.exp(-drift))) * (np.sum(r3) - (np.exp(drift)*np.sum(r2) ) )
k
# Out:
# -0.7491830648886502

# %%
variance = (2*drift) /(len(r1) *(1 - np.exp(-2*drift))) * np.sum(r3 - (r2*np.exp(-drift)) - k*((1 - np.exp(-drift))))
variance
# Out:
# -0.04094951999053233

# %%
beta = drift
sig = np.sqrt(variance)

xo, yo = vasicek(df['3M'].iloc[-1], k, beta, sig, 1, 100, seed = 3)

rng = pd.date_range(df['Date'].iloc[-1], periods=101 , freq='B')
lib = pd.DataFrame({ 'Date': rng, '3M': yo}) 


plt.title('Simulation: 3-month LIBOR curve using Vasicek Model')
plt.plot(df['Date'], df['3M'], label = "Historical")
plt.plot(df_test['Date'], df_test['3M'], color = 'g', label = "Actual")
plt.plot(lib['Date'], lib['3M'], color = 'r', label = "Predicted")

plt.xlabel('Date')
plt.ylabel('Rate')
plt.legend()
plt.show()

# %% [markdown]
# ### Option Pricing

# %%
# Out:
# array([5])
